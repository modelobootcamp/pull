# %%
# SQL Alchemy
from sqlalchemy import create_engine

#database_path = "../Resources/icecreamstore.sqlite"

import pymysql
import pandas as pd
pymysql.install_as_MySQLdb()



engine = create_engine("mysql://root:chichi1212@localhost/sakila")


conn = engine.connect()

# %%
# Create an engine to connect to the database

sql = '''
select f.title, a.first_name, a.last_name
from film f
inner join film_actor fa on fa.film_id = f.film_id
inner join actor a on a.actor_id = fa.actor_id;


'''

data = pd.read_sql( sql, conn)

# %%
# Query All Records in the the Database
data
# Out:
#                       title first_name last_name
# 0          ACADEMY DINOSAUR   PENELOPE   GUINESS
# 1      ANACONDA CONFESSIONS   PENELOPE   GUINESS
# 2               ANGELS LIFE   PENELOPE   GUINESS
# 3     BULWORTH COMMANDMENTS   PENELOPE   GUINESS
# 4             CHEAPER CLYDE   PENELOPE   GUINESS
# 5        COLOR PHILADELPHIA   PENELOPE   GUINESS
# 6           ELEPHANT TROJAN   PENELOPE   GUINESS
# 7       GLEAMING JAWBREAKER   PENELOPE   GUINESS
# 8            HUMAN GRAFFITI   PENELOPE   GUINESS
# 9            KING EVOLUTION   PENELOPE   GUINESS
# 10               LADY STAGE   PENELOPE   GUINESS
# 11          LANGUAGE COWBOY   PENELOPE   GUINESS
# 12         MULHOLLAND BEAST   PENELOPE   GUINESS
# 13         OKLAHOMA JUMANJI   PENELOPE   GUINESS
# 14              RULES HUMAN   PENELOPE   GUINESS
# 15              SPLASH GUMP   PENELOPE   GUINESS
# 16        VERTIGO NORTHWEST   PENELOPE   GUINESS
# 17      WESTWARD SEABISCUIT   PENELOPE   GUINESS
# 18       WIZARD COLDBLOODED   PENELOPE   GUINESS
# 19         ADAPTATION HOLES       NICK  WAHLBERG
# 20            APACHE DIVINE       NICK  WAHLBERG
# 21                BABY HALL       NICK  WAHLBERG
# 22           BULL SHAWSHANK       NICK  WAHLBERG
# 23          CHAINSAW UPTOWN       NICK  WAHLBERG
# 24          CHISUM BEHAVIOR       NICK  WAHLBERG
# 25         DESTINY SATURDAY       NICK  WAHLBERG
# 26          DRACULA CRYSTAL       NICK  WAHLBERG
# 27         FIGHT JAWBREAKER       NICK  WAHLBERG
# 28               FLASH WARS       NICK  WAHLBERG
# 29          GILBERT PELICAN       NICK  WAHLBERG
# ...                     ...        ...       ...
# 5432           HOPE TOOTSIE      JULIA   FAWCETT
# 5433             LUKE MUMMY      JULIA   FAWCETT
# 5434             MULAN MOON      JULIA   FAWCETT
# 5435               OPUS ICE      JULIA   FAWCETT
# 5436    POLLOCK DELIVERANCE      JULIA   FAWCETT
# 5437    RIDGEMONT SUBMARINE      JULIA   FAWCETT
# 5438        SHANGHAI TYCOON      JULIA   FAWCETT
# 5439       SHAWSHANK BUBBLE      JULIA   FAWCETT
# 5440         THEORY MERMAID      JULIA   FAWCETT
# 5441             WAIT CIDER      JULIA   FAWCETT
# 5442            AFRICAN EGG      THORA    TEMPLE
# 5443            BADMAN DAWN      THORA    TEMPLE
# 5444        BLANKET BEVERLY      THORA    TEMPLE
# 5445    CANDIDATE PERDITION      THORA    TEMPLE
# 5446            CAROL TEXAS      THORA    TEMPLE
# 5447    CHRISTMAS MOONSHINE      THORA    TEMPLE
# 5448     GALAXY SWEETHEARTS      THORA    TEMPLE
# 5449            HOCUS FRIDA      THORA    TEMPLE
# 5450        INSIDER ARIZONA      THORA    TEMPLE
# 5451     INTERVIEW LIAISONS      THORA    TEMPLE
# 5452             JADE BUNCH      THORA    TEMPLE
# 5453           LOVER TRUMAN      THORA    TEMPLE
# 5454       LOVERBOY ATTACKS      THORA    TEMPLE
# 5455           MADISON TRAP      THORA    TEMPLE
# 5456              RANDOM GO      THORA    TEMPLE
# 5457       TELEGRAPH VOYAGE      THORA    TEMPLE
# 5458        TROJAN TOMORROW      THORA    TEMPLE
# 5459        VIRGINIAN PLUTO      THORA    TEMPLE
# 5460       WARDROBE PHANTOM      THORA    TEMPLE
# 5461         WRONG BEHAVIOR      THORA    TEMPLE
#
# [5462 rows x 3 columns]

# %%
# Query Single Record in the the Database
